# %% [markdown]
# ### seaborn is a python library used to make statistical graphs. it is used to visualize the data
#
# ``` syntax:
#   seaborn.distplot(a=None, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None, x=None)  ```

# %% [markdown]
# parameters

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# parameter
# > a: Series, 1d-array or list.

# %%
sns.displot([1,2,3,4,5])

# %%
obj=['sunday  ', 'monday  ','tuesday  ','wednesday  ','thursday  ','friday  ','saturday  ']

# %%
# Out:
# ['sunday  ', 'monday  ', 'tuesday  ', 'wednesday  ', 'thursday  ', 'friday  ', 'saturday  ']

# %%
sns.displot(obj)

# %% [markdown]
# Parmeter:
# > The towers or bars of a histogram are called bin.
# >> bins: argurments for matplotlib hist(), or None, optional
# >>> width of each bin is =(max value of data- min value of data)/total number of bins

# %%
sns.displot([1,2,3,4,5], bins=2)

# %% [markdown]
# #### parameters:
# > hist: bool,optional

# %%
sns.displot([1,2,3])

# %%
#style must be one of white, dark, whitegrid, darkgrid, ticks
sns.set(style="ticks")

# %% [markdown]
# syntax: sns.distplot(arr, hist=False) to visualize random distributions

# %%
sns.displot([0,1,2,3,4,5]) #distribution plot is used to plot a histogram

# %%
sns.distplot([0,1,2,3,4,5], hist=False)
# Out:
# C:\Users\hp\Downloads\anconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
np.random.seed(0)

# %%
x=np.random.randn(100)

# %%
a=sns.displot(x)

# %%
a=sns.displot()
